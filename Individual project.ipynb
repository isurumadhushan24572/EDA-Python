# %% [markdown]
# # DS Project(EDA)

# %% [markdown]
# #### Student ID:- 24572   ||                                                   Name:- MKIM Rohana

# %% [markdown]
# ## 1) Requirement:- Identify the trends of the shoping items

# %% [markdown]
# ## 2) Data gathering:- Used secondory dataset from kaggle

# %% [markdown]
# #### Import Pandas Library

# %%
import pandas as pd # pandas is used for the data manipulation

# %% [markdown]
# ### Import Data Frame

# %%
df=pd.read_csv("shopping_trends.csv") #read_csv() is used for reading csv file

# %% [markdown]
# ### Get the sample 5 rows of the DataFrame

# %%
df.sample(5)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 396           397   46    Male          Dress     Clothing
# 1690         1691   40    Male           Coat    Outerwear
# 3651         3652   20  Female        Handbag  Accessories
# 1172         1173   59    Male           Coat    Outerwear
# 2343         2344   58    Male          Socks     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 396                      88  South Carolina    S   Black    Fall
# 1690                     30          Nevada    M   Black  Summer
# 3651                     32         Arizona    M  Yellow  Spring
# 1172                     68          Oregon    L   Peach  Spring
# 2343                     49        Maryland    M     Red  Summer
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 396             3.9                 Yes  Bank Transfer        Standard
# 1690            3.2                  No           Cash   Free Shipping
# ...

# %% [markdown]
# ### Get the First 5 rows of the DataFrame

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# ### Get the Last 5 rows of the DataFrame

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3923         3345   62  Female            Hat  Accessories
# 3924         3346   28  Female        Handbag  Accessories
# 3925         3347   30  Female          Jeans     Clothing
# 3926         3348   22  Female          Shoes     Footwear
# 3927         3349   28  Female        T-shirt     Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 3923                     48     Washington   XL    Magenta    Fall
# 3924                     91        Florida    M  Turquoise  Summer
# 3925                     99       Oklahoma    M      Black  Summer
# 3926                     70           Iowa   XL       Cyan  Summer
# 3927                     74  New Hampshire    L       Gray  Winter
#
#       Review Rating Subscription Status Payment Method Shipping Type  \
# 3923            4.3                  No     Debit Card           NaN
# ...

# %% [markdown]
# ### Get the no of rows and columns

# %%
df.shape # Here provide sequentinaly no of rows & no of columns as tuple
# Out:
# (3928, 20)

# %% [markdown]
# ### Get the columns names

# %%
df.columns # Provide all the columns as a list
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases', 'Location.1'],
#       dtype='object')

# %% [markdown]
# ### Get the  information of the data set

# %%
df.info() #This method prvide null values counts and it's data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3928 entries, 0 to 3927
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3928 non-null   int64
#  1   Age                       3928 non-null   int64
#  2   Gender                    3928 non-null   object
#  3   Item Purchased            3928 non-null   object
#  4   Category                  3928 non-null   object
#  5   Purchase Amount (USD)     3928 non-null   int64
#  6   Location                  3928 non-null   object
#  7   Size                      3928 non-null   object
#  8   Color                     3928 non-null   object
#  9   Season                    3928 non-null   object
#  10  Review Rating             3928 non-null   float64
#  11  Subscription Status       3928 non-null   object
#  12  Payment Method            3928 non-null   object
# ...

# %% [markdown]
# ## 3) Data cleaning and preprocessing.

# %% [markdown]
# ### Check dataset has missing values

# %%
df.isnull().sum() # isnull() check the whether null or not and sum() used to the get the counts
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               5
# Discount Applied            5
# Promo Code Used             5
# Previous Purchases          5
# Preferred Payment Method    5
# Frequency of Purchases      5
# Location.1                  5
# dtype: int64

# %% [markdown]
# ### If the data set has any missing values we can use delete complete rows or adding dummy values for this

# %% [markdown]
# ### Deleting Missing Values from Data Frame Permenantly

# %%
df.dropna(inplace=True) # is used delete all rows that contains null values(Also that's not need for this data set)

# %% [markdown]
# ### Check Duplicate Values

# %%
df.duplicated().sum() # duplicated() is used for check duplicated and sum() is used for get the count
# Out:
# 23

# %% [markdown]
# ### If the dataset has duplicates values we have to delete it in the cleancing process & for that use drop_duplicates()

# %%
df.drop_duplicates(inplace=True) # if want to delete that duplicated rows permanantly used inplace=True,if not inplace=False

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### How Delete Rows?

# %%
df.drop(range(0,100),axis=0,inplace=False)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 100           101   62    Male     Sunglasses  Accessories
# 101           102   27    Male           Coat    Outerwear
# 102           103   51    Male          Socks     Clothing
# 103           104   54    Male          Boots     Footwear
# 104           105   55    Male     Sunglasses  Accessories
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 100                      98   South Dakota    M     Maroon    Fall
# 101                      85   North Dakota   XL      White  Spring
# ...

# %% [markdown]
# ### How Delete columns? (Need "Lacation.1" column which is a duplicated of "Location" Column)

# %%
df.drop("Location.1",axis=1,inplace=True)

# %% [markdown]
# ## 4) Data analysing & Visualization

# %% [markdown]
# ### Get the Number of Unique Values of the all columns in dataframe

# %%
df.nunique()
# Out:
# Customer ID                 3900
# Age                           53
# Gender                         2
# Item Purchased                25
# Category                       4
# Purchase Amount (USD)         81
# Location                      50
# Size                           4
# Color                         25
# Season                         4
# Review Rating                 26
# Subscription Status            2
# Payment Method                 6
# Shipping Type                  6
# Discount Applied               2
# Promo Code Used                2
# Previous Purchases            50
# Preferred Payment Method       6
# Frequency of Purchases         7
# dtype: int64

# %% [markdown]
# ### Get the unique labels of a column

# %%
df.Gender.unique()# get the unique labels of the Gender Column
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.Category.unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
df["Preferred Payment Method"].unique()
# Out:
# array(['Venmo', 'Cash', 'Credit Card', 'PayPal', 'Bank Transfer',
#        'Debit Card'], dtype=object)

# %%
import matplotlib.pyplot as plt # matplotlib is used for visualizing process

# %% [markdown]
# ### Use Histogram the identify the individually behavior of each varaiable

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Customer ID'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'Purchase Amount (USD)'}>,
#         <AxesSubplot:title={'center':'Review Rating'}>],
#        [<AxesSubplot:title={'center':'Previous Purchases'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #### Information
#
# 1) when cosidering Age (30 - 40) people buying power is less than Age (50 - 60) people
#
# 2) Number of the purchase item which is range (80-100) hiegher than Number of the purchase item which is range (40-60)$
#
# 3) More review & rating range is (4.5 to 5.0)

# %% [markdown]
# ### Get Box Plot for the identify Data Range & outliers

# %%
df.plot.box(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### This can't see properly  counts of the (Age,Purchase Amount (USD),.....). Thus we have to use subplots of it

# %%
df.plot.box(subplots=True,figsize=(15, 6)) #subplots has enabled using ==> subplots=True
# Out:
# Customer ID                 AxesSubplot(0.125,0.11;0.133621x0.77)
# Age                      AxesSubplot(0.285345,0.11;0.133621x0.77)
# Purchase Amount (USD)     AxesSubplot(0.44569,0.11;0.133621x0.77)
# Review Rating            AxesSubplot(0.606034,0.11;0.133621x0.77)
# Previous Purchases       AxesSubplot(0.766379,0.11;0.133621x0.77)
# dtype: object

# %% [markdown]
# #### Information

# %% [markdown]
# 1) Customer ID Range is (0-4000)
#
# 2) Age Range(20-70)
#
# 3) Purchase Amount (USD) Range (20-100)
#
# 4) Review Rating Range( (2.5) - (5.0) )
#
# 5) Previous Purchases Range (0-50)

# %% [markdown]
# ### Get the Bar chart representing with the count of items Purchased by Category

# %%
category_counts = df['Category'].value_counts()#for the data visualization has to get numeric values for that use values_counts() for string

plt.figure(figsize=(10, 6))  #by changing figsize(,) can change the figure size manually
category_counts.plot(kind='bar',color="darkblue") # Bar chart with background color light blue
plt.title('Count of Items Purchased by Category') # Give the title
plt.xlabel('Category') # Give the x axis label
plt.ylabel('Count')    # Give the Y axis label
plt.show()

# %% [markdown]
# #### Information
#
# 1) Most purchased Item catogory is ==> Clothing
#
# 2) Lowest purchased Item catogory is ==> Outerwear
#
# 3) Accessorires Catogory Items have been purchased more than Footwear Catogory Items

# %% [markdown]
# ### Get the Bar chart representing  count of items Purchased by Category with Gender

# %%
category_Gender_counts = df[["Gender","Category"]].value_counts() # have to use list here due to the need more than one column
plt.figure(figsize=(10, 6))
category_Gender_counts.plot(kind='bar', color='skyblue')
plt.title('count of items Purchased by Category with Gender')
plt.xlabel('Gender with Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
#
# 1) Male's most purchasing catogory is Clothing
#
# 2) Male's least purchasing catogory is Footwear
#
# 3) Female's most purchasing catogory is Clothing
#
# 4) Female's least purchasing catogory is Footwear
#
# 5) Male's Footwear purchasing and Female's Accessories purchasing approximately are equal

# %% [markdown]
# ### Get the Pie chart representing  count of Promo Code Used with Gender

# %%
category_Gender_counts= df[["Gender","Promo Code Used"]].value_counts()

plt.figure(figsize=(5, 5))
category_Gender_counts.plot(kind='pie')
plt.title('count of Promo Code Used with Gender')
plt.xlabel('Gender with Promo Code Used')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### Information
#
# 1) More male's have been used promo code for the purchasing items
#
# 2) All femal's haven't been used promo code for the purchasing items

# %% [markdown]
# ### Area Plot for the Item purchased by catogory with Location

# %%
category_Location_counts =df[["Location","Category"]].value_counts()

plt.figure(figsize=(18, 2))
category_Location_counts .plot(kind='area')
plt.title('Area Plot for the Item purchased by catogory with Location')
plt.xlabel('Location with Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
# 1) California is the Location which highest purchased clothing Catogory Items
#
# 2) Connecticut is the location which highest purchased Accessorires Catogory Items
#
# 3) Utah is the location which highest purchased Footwear Catogory Items
#
# 4) Oregon is the location which highest purchased Outerwear Catogory Items

# %% [markdown]
# ### Line Plot for the Item purchased by Season

# %%
Item_Season_counts =df[["Item Purchased","Season"]].value_counts()

plt.figure(figsize=(18, 2))
Item_Season_counts.plot(kind='line')
plt.title('Line Plot for the Item purchased by Season')
plt.xlabel('Item Purchased with Season')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
# 1) In Fall Seasson Jscket ,Sandals and Pants  sells are high
#
# 2) In Summer Sesson Shorts selles are high.
#
# 3) In Spring Seasson Sunglass sellers are high.

# %% [markdown]
# ### Bar chart for the Item purchased by Size

# %%
Item_Size_counts =df[["Item Purchased","Size"]].value_counts()

plt.figure(figsize=(20, 2))
Item_Size_counts.plot(kind='bar')
plt.title('Bar chart for the Item purchased by Size')
plt.xlabel('Item Purchased with Size')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
# 1) According to this chart Heighest purchased items size are ==> M [Medium]
#
# 2) Lowest purchased items size are ==> XL [Extra Large]
#
# 3) In Medium size items most purchased item is Shirt
#
# 4) In Large size item most purchased item is Skirt
#
# 5) In small size item most purchased item is Jewlery

# %% [markdown]
# ### Bar chart for the Item purchased by Color

# %%
Item_Color_counts =df[["Category","Color"]].value_counts()

plt.figure(figsize=(20,5))
Item_Color_counts.plot(kind='bar')
plt.title('Line Plot for the Item purchased by Season')
plt.xlabel('Item Purchased with Season')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
#
# 1) In Clothing catogory items most purchased colrs are Teal, Marron, Black,Silver,Violet and Orange
#
# 2) In Accessories catogory items most purchased colrs are Olive, Blue, Gray, Peach and Magenta
#
# 3) In Footwear catogory items most purchased colrs are Olive, Yellow, Violet,Pink and silver
#
# 4) In outerwear catogory items most purchased colrs are Olive, Blue, Cyan, Violet and Lavender

# %% [markdown]
# ### Line chart for the Payment Methods

# %%
PaymentMethod_counts =df[["Payment Method"]].value_counts()

plt.figure(figsize=(20,5))
PaymentMethod_counts.plot(kind='line',color="aqua")
plt.title('Line chart for the Payment Methods')
plt.xlabel('Payment Methods')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
# 1) Credid Card is the heighest payment method
#
# 2) Bank Tranfer is the Lowest payment method
#
# 3) Cash payement is greater than paypal payment

# %%
category_Review_counts =df[["Category","Review Rating"]].value_counts()

plt.figure(figsize=(20,5))
category_Review_counts.plot(kind='bar')
plt.title('Line chart for the Payment Methods')
plt.xlabel('Payment Methods')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Line chart for Catogory by Discount

# %%
category_Discount_counts =df[["Category","Discount Applied"]].value_counts()

plt.figure(figsize=(15,5))
category_Discount_counts.plot(kind='line')
plt.title(' Line chart for Catogory by Discount')
plt.xlabel('Catogory with Discount Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
# 1) The height catogory that have applied dicount is clothing
#
# 2) The Lowest catogory that have applied dicount is Outerwear
#
# 3) In Every catogory number of the Discount applied is low than not applied Discount.

# %% [markdown]
# ### Bar chart for Frequency of Purchases by Season

# %%
Purchases_Season_counts =df[["Season","Frequency of Purchases"]].value_counts()

plt.figure(figsize=(15,10))
Purchases_Season_counts.plot(kind='bar',color="Blue")
plt.title(' Bar chart for Frequency of Purchases by Season')
plt.xlabel('Frequency of Purchases with Season')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Information
#
# 1) Most Fall Season items has purchased frequency is Annually
#
# 2) Most Spring Season items has purchased frequency is Weekly
#
# 3) Most Summer Season items has purchased frequency is Every 3 months

# %% [markdown]
# # Get Statistical Description for the whole data set

# %%
df.describe() #here provide cloumns std,mean,count and corrration which data type is number
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# ### For graphically represent (Min,Max,Cooraions) Can use Box Plot

# %%
df.plot.box(subplots=True,figsize=(15, 6)) #subplots has enabled using ==> subplots=True
# Out:
# Customer ID                 AxesSubplot(0.125,0.11;0.133621x0.77)
# Age                      AxesSubplot(0.285345,0.11;0.133621x0.77)
# Purchase Amount (USD)     AxesSubplot(0.44569,0.11;0.133621x0.77)
# Review Rating            AxesSubplot(0.606034,0.11;0.133621x0.77)
# Previous Purchases       AxesSubplot(0.766379,0.11;0.133621x0.77)
# dtype: object

# %% [markdown]
# ### Get dataframe with core relation of the Variables each other with statistically

# %%
df.corr() #corr() is used to calculate core relation between in pd.It's statistical measure which quantifies the degree to which to variables are related with each other
# Out:
#                        Customer ID       Age  Purchase Amount (USD)  \
# Customer ID               1.000000 -0.004079               0.011048
# Age                      -0.004079  1.000000              -0.010424
# Purchase Amount (USD)     0.011048 -0.010424               1.000000
# Review Rating             0.001343 -0.021949               0.030776
# Previous Purchases       -0.039159  0.040445               0.008063
#
#                        Review Rating  Previous Purchases
# Customer ID                 0.001343           -0.039159
# Age                        -0.021949            0.040445
# Purchase Amount (USD)       0.030776            0.008063
# Review Rating               1.000000            0.004229
# Previous Purchases          0.004229            1.000000

# %% [markdown]
# ### Heat Map with core Relation among variable

# %%
import seaborn as sn #Seaborn also data visualization library and seaborn library quickly create actractive statiscal plot and it is structured data set.
sn.heatmap(df.corr(),annot=True)
plt.rcParams["figure.figsize"]=(5,10)
plt.show()

# %% [markdown]
# ### Group by Gender with mean

# %%
df1=df.groupby("Gender").mean() # can't use groupby() directly for that has to provide aggrigate functions like=>[mean,average,max,mean,count] 
df2=df1.transpose() # To get accepted graph we have to transpose first
df2
# Out:
# Gender                      Female         Male
# Customer ID            3276.500000  1326.500000
# Age                      44.007212    44.097285
# Purchase Amount (USD)    60.249199    59.536199
# Review Rating             3.741426     3.753959
# Previous Purchases       24.596154    25.707014

# %% [markdown]
# ### Group by Category with Purchase Amount (USD)

# %%
df.groupby("Category").agg({"Purchase Amount (USD)":["count","sum","mean","max","min"]})
# Out:
#             Purchase Amount (USD)
#                             count     sum       mean  max min
# Category
# Accessories                  1240   74200  59.838710  100  20
# Clothing                     1737  104264  60.025331  100  20
# Footwear                      599   36093  60.255426  100  20
# Outerwear                     324   18524  57.172840  100  20

# %% [markdown]
# #### Information
#
# 1) Most purchased catogory is clothing
#
# 2) Clothing also the most earning catogory.
#
# 3) Average Clothing catogory item price is 60.025331$
#
# 4) All the catogory items price range is (20-100)$

# %% [markdown]
# ### Group by Item Purchased with Purchase Amount (USD)

# %%
df.groupby("Item Purchased").agg({"Purchase Amount (USD)":["count","sum","mean","max","min"]})
# Out:
#                Purchase Amount (USD)
#                                count    sum       mean  max min
# Item Purchased
# Backpack                         143   8636  60.391608   99  20
# Belt                             161   9635  59.844720  100  20
# Blouse                           171  10410  60.877193  100  20
# Boots                            144   9018  62.625000  100  21
# Coat                             161   9275  57.608696  100  20
# Dress                            166  10320  62.168675  100  20
# Gloves                           140   8477  60.550000   99  21
# Handbag                          153   8857  57.888889  100  21
# Hat                              154   9375  60.876623   98  20
# Hoodie                           151   8767  58.059603  100  20
# Jacket                           163   9249  56.742331  100  20
# Jeans                            124   7548  60.870968   99  20
# Jewelry                          171  10010  58.538012  100  20
# ...

# %% [markdown]
# #### Information
#
# 1) Most purchased item are Blouse,Jewelry,Pants
#
# 2) Blouse also the most earning item.
#
# 3) Average T-shirts and Dress price is 62$

# %% [markdown]
# ### Bar chart for the above Dataframe group with Gender

# %%
df2.filter(items=["Age","Purchase Amount (USD)","Review Rating","Previous Purchases"],axis=0).plot.bar(figsize=(15, 3)) # filter(items=[]) is used for filter required cloumns or rows data changing axis
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Area Plot for the Above Bar chart

# %%
df2.filter(items=["Age","Purchase Amount (USD)","Review Rating","Previous Purchases"],axis=0).plot.area(figsize=(15, 3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Information
#
# 1) According to the above bar chart and area graph Most age people are Male
#
# 2) Male Buying power are high than Female
#
# 3) Male review Rating are high than Female
#
# 4) Male Previous Purchases are high than Female
